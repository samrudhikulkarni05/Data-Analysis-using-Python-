# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
car=pd.read_csv("car-sales-extended.csv")
car
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
car.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
car.mode()
# Out:
#       Make Colour  Odometer (KM)  Doors  Price
# 0   Toyota  White        73869.0    4.0   3974
# 1      NaN    NaN       129188.0    NaN   4566
# 2      NaN    NaN            NaN    NaN   7813
# 3      NaN    NaN            NaN    NaN   7994
# 4      NaN    NaN            NaN    NaN   8260
# 5      NaN    NaN            NaN    NaN  10429
# 6      NaN    NaN            NaN    NaN  11648
# 7      NaN    NaN            NaN    NaN  12392
# 8      NaN    NaN            NaN    NaN  12402
# 9      NaN    NaN            NaN    NaN  13560
# 10     NaN    NaN            NaN    NaN  15154
# 11     NaN    NaN            NaN    NaN  16519
# 12     NaN    NaN            NaN    NaN  17076
# 13     NaN    NaN            NaN    NaN  17520
# 14     NaN    NaN            NaN    NaN  18919
# 15     NaN    NaN            NaN    NaN  28414

# %%
car.sum()
# Out:
# Make             HondaBMWHondaToyotaNissanHondaToyotaHondaNissa...
# Colour           WhiteBlueWhiteWhiteBlueRedBlueWhiteWhiteBlueWh...
# Odometer (KM)                                            131073708
# Doors                                                         4014
# Price                                                     16045665
# dtype: object

# %%
car.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car['Make']
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: >]], dtype=object)

# %%
car.plot.bar()
# Out:
# <Axes: >

# %%
car['Price'].plot.bar()
# Out:
# <Axes: >

# %%
car['Price'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Price'>

# %%
car['Price'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
car['Price'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car['Price'].plot()
# Out:
# <Axes: >

# %%
car['Doors'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car.iloc[232]
# Out:
# Make             Toyota
# Colour             Blue
# Odometer (KM)    148421
# Doors                 4
# Price              9953
# Name: 232, dtype: object

# %%
car.loc[232]
# Out:
# Make             Toyota
# Colour             Blue
# Odometer (KM)    148421
# Doors                 4
# Price              9953
# Name: 232, dtype: object

# %%
car.loc[232:278].plot()
# Out:
# <Axes: >

# %%
car[car["Price"]<=1000]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
car['prodata']=car['Doors']*car['Price']
car
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  prodata
# 0     Honda  White          35431      4  15323    61292
# 1       BMW   Blue         192714      5  19943    99715
# 2     Honda  White          84714      4  28343   113372
# 3    Toyota  White         154365      4  13434    53736
# 4    Nissan   Blue         181577      3  14043    42129
# ..      ...    ...            ...    ...    ...      ...
# 995  Toyota  Black          35820      4  32042   128168
# 996  Nissan  White         155144      3   5716    17148
# 997  Nissan   Blue          66604      4  31570   126280
# 998   Honda  White         215883      4   4001    16004
# 999  Toyota   Blue         248360      4  12732    50928
#
# [1000 rows x 6 columns]

# %%
car.drop('prodata',axis=1,inplace=True)
car
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car.nunique()
# Out:
# Make               4
# Colour             5
# Odometer (KM)    998
# Doors              3
# Price            984
# dtype: int64

# %%
pd.crosstab(car['Price'],car['Doors'])
# Out:
# Doors  3  4  5
# Price
# 2796   0  1  0
# 3125   0  1  0
# 3247   0  1  0
# 3300   0  1  0
# 3509   0  1  0
# ...   .. .. ..
# 48419  0  0  1
# 48686  0  0  1
# 50822  0  0  1
# 50868  1  0  0
# 52458  0  0  1
#
# [984 rows x 3 columns]

# %%
car.plot(kind='bar')
# Out:
# <Axes: >

# %%
car['Price'].plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.crosstab(car['Price'],car['Doors']).plot.bar()
# Out:
# <Axes: xlabel='Price'>

# %%
import seaborn as sns

# %%
plt.subplot(3,2,1)
sns.kdeplot(car["Price"])
plt.subplot(3,2,2)
sns.kdeplot(car["Price"])

plt.subplot(3,2,3)
sns.kdeplot(car["Doors"])
plt.subplot(3,2,4)
sns.kdeplot(car["Price"])

plt.subplot(3,2,5)
sns.kdeplot(car["Price"])
plt.subplot(3,2,6)
sns.kdeplot(car["Price"])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=car["Price"],y=car["Doors"],data=car)
# Out:
# <Axes: xlabel='Price', ylabel='Doors'>

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=car["Price"],y=car["Make"],data=car)
# Out:
# <Axes: xlabel='Price', ylabel='Make'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(car,alpha=0.2,figsize=(10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='Odometer (KM)', ylabel='Odometer (KM)'>,
#         <Axes: xlabel='Doors', ylabel='Odometer (KM)'>,
#         <Axes: xlabel='Price', ylabel='Odometer (KM)'>],
#        [<Axes: xlabel='Odometer (KM)', ylabel='Doors'>,
#         <Axes: xlabel='Doors', ylabel='Doors'>,
#         <Axes: xlabel='Price', ylabel='Doors'>],
#        [<Axes: xlabel='Odometer (KM)', ylabel='Price'>,
#         <Axes: xlabel='Doors', ylabel='Price'>,
#         <Axes: xlabel='Price', ylabel='Price'>]], dtype=object)
