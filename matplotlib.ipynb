# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='o')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='x')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='2')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='p')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='3')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='p',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,marker='3')
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D-.k',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'h-.k',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D-.m',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D-.b',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D--k',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D--b',ms=20)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.plot(x,y,'D--b',ms=10)
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.scatter(x,y)
plt.show()

# %%
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.scatter(x,y,marker="D",c='#ff5733', edgecolors='#CD5C5C')
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()

# %%
y=np.array([1,2,3,4,5])
plt.pie(y,labels=['A','B','C','D','E'],autopct='%2.1f%%')
plt.show()

# %%
y=np.array([1,2,3,4,5])
AA=['A','B','C','D','E']
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.pie(y,labels=AA,autopct='%2.1f%%',colors=cc)
plt.legend(loc="upper right")
plt.show()

# %%
y=np.array([1,2,3,4,5])
AA=['A','B','C','D','E']
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
bb=[0.3,0,0,0,0]
plt.pie(y,labels=AA,autopct='%2.1f%%',colors=cc,explode=bb)
plt.legend(loc="upper right")
plt.show()

# %%
y=np.array([1,2,3,4,5])
AA=np.array(['A','B','C','D','E'])
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.bar(AA,y,label=AA,color=cc)
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.legend()
plt.show()

# %%
y=np.array([1,2,3,4,5])
AA=np.array(['A','B','C','D','E'])
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.barh(AA,y,label=AA,color=cc)
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.legend()
plt.show()

# %%
import numpy as np

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x,histtype='step',color='#881230')
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x,histtype='bar',color='#881230')
plt.show()

# %%
x=np.random.normal(170,10,250)
plt.hist(x,histtype='step',color='#881230',bins=30)
plt.show()

# %%
x=np.random.uniform(170,10,250)
plt.hist(x,histtype='step',color='#881230')
plt.show()

# %%
x=np.random.uniform(170,10,250)
plt.hist(x,histtype='bar',color='#881230')
plt.show()

# %%
x=np.random.poisson(170,10)
plt.hist(x,histtype='bar',color='#881230')
plt.show()

# %%
x=np.random.rayleigh(170,250)
plt.hist(x,histtype='bar',color='#881230')
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,6,8])
plt.subplot(1,2,1)
plt.plot(x,y)
x1=np.array([3,1,2,3])
y1=np.array([19,34,20,23])
plt.subplot(1,2,2)
plt.plot(x1,y1)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,6,8])
plt.subplot(3,2,1)
plt.plot(x,y)

x1=np.array([3,1,2,3])
y1=np.array([19,34,20,23])
plt.subplot(3,2,2)
plt.plot(x1,y1)
plt.show()

y3=np.array([1,2,3,4,5])
AA=np.array(['A','B','C','D','E'])
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.barh(AA,y3,label=AA,color=cc)
plt.legend()
x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.scatter(x,y,marker="D",c='#ff5733', edgecolors='#CD5C5C')

x=np.array([1,2,3,4,5])
y=np.array([12,33,44,66,45])
plt.scatter(x,y,marker="D",c='#ff5733', edgecolors='#CD5C5C')



y4=np.array([1,2,3,4,5])
AA=['A','B','C','D','E']
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.pie(y4,labels=AA,autopct='%2.1f%%',colors=cc)
plt.legend(loc="upper right")
plt.subplot(1,1,1)
plt.show()

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,6,8])
plt.subplot(3,2,1)
plt.plot(x,y)

x1=np.array([3,1,2,3])
y1=np.array([19,34,20,23])
plt.subplot(3,2,2)

x3=np.random.normal(170,10,250)
plt.hist(x,histtype='step',color='#881230')
plt.subplot(3,2,3)

y3=np.array([1,2,3,4,5])
AA=['A','B','C','D','E']
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
bb=[0.3,0,0,0,0]
plt.pie(y3,labels=AA,autopct='%2.1f%%',colors=cc,explode=bb)
plt.subplot(3,2,4)

y4=np.array([1,2,3,4,5])
AA=np.array(['A','B','C','D','E'])
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.bar(AA,y4,label=AA,color=cc)
plt.subplot(3,2,5)

y5=np.array([1,2,3,4,5])
AA=np.array(['A','B','C','D','E'])
cc=['#FFBF00','#6495ED','#9FE2BF','#DE3163','#CCCCFF']
plt.barh(AA,y5,label=AA,color=cc)
plt.subplot(3,2,6)


plt.show()

# %%
plt.subplots(figsize=(20,20))
y=np.array([22,12,42,53,56,79])
plt.subplot(3,2,1)
plt.pie(y,labels=["A","B","C","D","E","F"],autopct='%2.1f%%')

x=np.array([1,2,3,4,5])
y=np.array([6,7,8,9,10])
plt.subplot(3,2,2)
plt.plot (x,y, 'h--m',ms=15)

y=np.array([22,12,42,53,56,79])
plt.subplot(3,2,3)
AA=["A","B","C","D","E","F"]
CC=['#8e44ad','#2e86c1','#17202a','#5dade2','#0e6251','#e74c3c']
plt.bar(AA,y,color=CC,label=AA)

x=np.random.normal(170,10,250)
plt.subplot(3,2,4)
plt.hist(x,histtype='bar',color="#e74c3c",bins=20)

y=np.array([22,12,42,53,56,79])
plt.subplot(3,2,5)
AA=["A","B","C","D","E","F"]
CC=['#8e44ad','#2e86c1','#17202a','#5dade2','#0e6251','#e74c3c']
plt.barh(AA,y,color=CC,label=AA)

a=np.array([1,2,4,5,6])
b=np.array([3,7,8,9,1])
plt.subplot(3,2,6)
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.arange(0, 5*np.pi, 0.1)
y = np.sin(x)
plt.plot(x, y, color='green')
plt.subplot(3,2,1)
plt.show()

x1 = np.arange(0, 5*np.pi, 0.1)
y1= np.cos(x1)
plt.plot(x1, y1, color='green')
plt.subplot(3,2,2)
plt.show()

x3 = np.arange(0, 5*np.pi, 0.1)
y3= np.tan(x3)
plt.plot(x3, y3, color='green')
plt.subplot(3,2,3)
plt.show()


x2 = np.arange(0, 5*np.pi, 0.1)
y2= np.log(x2)
plt.plot(x2, y2, color='green')
plt.subplot(3,2,4)
plt.show()

x4 = np.arange(0, 5*np.pi, 0.1)
y4= np.exp(x4)
plt.plot(x4, y4, color='green')
plt.subplot(3,2,5)
plt.show()


x5= np.arange(0, 5*np.pi, 0.1)
m=0.7
c=2
y6=((m*x))+c
plt.show()
# Out:
# C:\Users\samru\AppData\Local\Temp\ipykernel_20804\3595067568.py:21: RuntimeWarning: divide by zero encountered in log
#   y2= np.log(x2)

# %%
x=np.linspace(5,10,100)
plt.subplot(3,2,1)
plt.plot(x,np.sin(x))

a=np.linspace(0,105,150)
plt.subplot(3,2,2)
plt.plot(a,np.cos(a))


t=np.linspace(0,100,150)
plt.subplot(3,2,3)
plt.plot(t,np.tan(t))

a=np.linspace(0,110,160)
plt.subplot(3,2,4)
plt.plot(a,np.log(a))


e=np.linspace(0,10,150)
plt.subplot(3,2,5)
plt.plot(e,np.exp(e))

x=np.linspace(5,10,100)
m=0.7
c=2
y=(m*(x))+c
plt.subplot(3,2,6)
plt.plot(x,y)
plt.show()
# Out:
# C:\Users\samru\AppData\Local\Temp\ipykernel_20804\1062971738.py:16: RuntimeWarning: divide by zero encountered in log
#   plt.plot(a,np.log(a))

# %%
x=np.random.normal(50)
y=np.random.normal(60)
plt.hist(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\anaconda3\Lib\site-packages\numpy\lib\histograms.py:419, in _get_bin_edges(a, bins, range, weights)
#     418 try:
# --> 419     n_equal_bins = operator.index(bins)
#     420 except TypeError as e:
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 3
#       1 x=np.random.normal(50)
#       2 y=np.random.normal(60)
# ----> 3 plt.hist(x,y)
#       4 plt.show()
#
# File C:\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3440, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3415 @_copy_docstring_and_deprecators(Axes.hist)
# ...

# %%
y=np.array([57,43])
AA=['A','B']
cc=['#FFBF00','#6495ED']
plt.pie(y,labels=AA,autopct='%2.1f%%',colors=cc)
plt.legend(loc="upper right")
plt.show()
