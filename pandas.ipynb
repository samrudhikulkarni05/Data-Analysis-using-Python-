# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
car=pd.Series(["BMW","Honda","Toyta","Nisaan"])
print(car)
print(type(car))
# Out:
# 0       BMW
# 1     Honda
# 2     Toyta
# 3    Nisaan
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
color=pd.Series(["pink","blue","orange","red"])
print(color)
print(type(color))
# Out:
# 0      pink
# 1      blue
# 2    orange
# 3       red
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
car_data=pd.DataFrame({"Brand": car,
                    "Colour":color})
car_data
# Out:
#     Brand  Colour
# 0     BMW    pink
# 1   Honda    blue
# 2   Toyta  orange
# 3  Nisaan     red

# %%
hd=pd.read_csv("heart-disease.csv")
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
db=pd.read_csv("diabetes.csv")
db
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
car=pd.read_csv("car-sales-extended-missing-data.csv")
car
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
carExtend=pd.read_csv("car-sales-extended.csv")
carExtend
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
carsell=pd.read_csv("car-sales-missing-data.csv")
carsell
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
w=pd.read_csv("winequality.csv")
w
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Describing Data

# %%
hd.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
hd.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
hd.mean()  #mode,sd,verients,sum perform all
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
hd.mode()
# Out:
#     age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  58.0  1.0  0.0     120.0   197  0.0      1.0    162.0    0.0      0.0
# 1   NaN  NaN  NaN       NaN   204  NaN      NaN      NaN    NaN      NaN
# 2   NaN  NaN  NaN       NaN   234  NaN      NaN      NaN    NaN      NaN
#
#    slope   ca  thal  target
# 0    2.0  0.0   2.0     1.0
# 1    NaN  NaN   NaN     NaN
# 2    NaN  NaN   NaN     NaN

# %%
hd.var()
# Out:
# age           82.484558
# sex            0.217166
# cp             1.065132
# trestbps     307.586453
# chol        2686.426748
# fbs            0.126877
# restecg        0.276528
# thalach      524.646406
# exang          0.220707
# oldpeak        1.348095
# slope          0.379735
# ca             1.045724
# thal           0.374883
# target         0.248836
# dtype: float64

# %%
hd.sum()
# Out:
# age         16473.0
# sex           207.0
# cp            293.0
# trestbps    39882.0
# chol        74618.0
# fbs            45.0
# restecg       160.0
# thalach     45343.0
# exang          99.0
# oldpeak       315.0
# slope         424.0
# ca            221.0
# thal          701.0
# target        165.0
# dtype: float64

# %%
hd.std()
# Out:
# age          9.082101
# sex          0.466011
# cp           1.032052
# trestbps    17.538143
# chol        51.830751
# fbs          0.356198
# restecg      0.525860
# thalach     22.905161
# exang        0.469794
# oldpeak      1.161075
# slope        0.616226
# ca           1.022606
# thal         0.612277
# target       0.498835
# dtype: float64

# %%
hd.median()
# Out:
# age          55.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     153.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %%
hd.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# # Viewing and Selecting of data

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
hd.tail(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# 296      1   0     2       0
# ...

# %%
hd.head(15)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hd['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
x=hd['age']
y=hd['fbs']
plt.scatter(x,y,color='#881230',edgecolors="yellow")
plt.legend(loc="upper right")
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()
# Out:
# C:\Users\samru\AppData\Local\Temp\ipykernel_18728\2632164853.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right")

# %%
x=hd['cp']
y=hd['ca']
plt.scatter(x,y,color="blue",marker="h")
plt.legend(loc="upper right")
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()
# Out:
# C:\Users\samru\AppData\Local\Temp\ipykernel_18728\3899277152.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right")

# %%
x=hd['chol']
y=hd['sex']
plt.scatter(x,y,marker="d",edgecolors="green",color="blue")
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()

# %%
x=hd['slope']
y=hd['target']
plt.scatter(x,y,marker="d",color="blue")
plt.legend(loc="upper right")
plt.title("sports watch data")
plt.xlabel("Average pluse")
plt.ylabel("Calerie Range")
plt.show()
# Out:
# C:\Users\samru\AppData\Local\Temp\ipykernel_18728\60920532.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right")

# %%
hd.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hd.plot.bar()
# Out:
# <Axes: >

# %%
hd['age'].plot.bar()
# Out:
# <Axes: >

# %%
hd['target'].plot.bar()
# Out:
# <Axes: >

# %%
hd['target'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='target'>

# %%
hd['target'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
hd['target'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
hd['target'].plot()
# Out:
# <Axes: >

# %%
hd['slope'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
hd['slope'].value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
hd['slope'].value_counts().plot()
# Out:
# <Axes: xlabel='slope'>

# %%
hd['slope'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='slope'>

# %% [markdown]
# ## Loc and iloc

# %%
ani=pd.Series(["cat","dog","cow","ox"],index=[1,6,8,5])
ani
# Out:
# 1    cat
# 6    dog
# 8    cow
# 5     ox
# dtype: object

# %%
ani.loc[1]
# Out:
# 'cat'

# %%
ani.iloc[1]
# Out:
# 'dog'

# %%
hd.iloc[232]
# Out:
# age          55.0
# sex           1.0
# cp            0.0
# trestbps    160.0
# chol        289.0
# fbs           0.0
# restecg       0.0
# thalach     145.0
# exang         1.0
# oldpeak       0.8
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 232, dtype: float64

# %%
hd.loc[232]
# Out:
# age          55.0
# sex           1.0
# cp            0.0
# trestbps    160.0
# chol        289.0
# fbs           0.0
# restecg       0.0
# thalach     145.0
# exang         1.0
# oldpeak       0.8
# slope         1.0
# ca            1.0
# thal          3.0
# target        0.0
# Name: 232, dtype: float64

# %%
hd.loc[232].plot()
# Out:
# <Axes: >

# %%
hd.loc[232:278].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Conditional feltering

# %%
hd[hd["target"]==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 162   41    1   1       120   157    0        1      182      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd["age"]>50]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
hd[hd["age"]>=50]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
hd[hd["slope"]==50]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
hd[hd["chol"]<100]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
hd[hd["chol"]>100]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd["fbs"]==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 296   63    0   0       124   197    0        1      136      1      0.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 1        0   0     2       1
# 2        2   0     2       1
# ...

# %%
hd[hd["sex"]==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 3     56    1   1       120   236    0        1      178      0      0.8
# 5     57    1   0       140   192    0        1      148      0      0.4
# 7     44    1   1       120   263    0        1      173      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 295   63    1   0       140   187    0        0      144      1      4.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd["thalach"]=>132]
# Out:
#   Cell In[57], line 1
#     hd[hd["thalach"]=>132]
#                     ^
# SyntaxError: invalid syntax

# %%
hd[hd["thalach"]>132]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 300   68    1   0       144   193    1        1      141      0      3.4
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd["thalach"]<132]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 17    66    0   3       150   226    0        1      114      0      2.6
# 27    51    1   2       110   175    0        1      123      0      0.6
# 34    51    1   3       125   213    0        0      125      1      1.4
# 48    53    0   2       128   216    0        0      115      0      0.0
# 60    71    0   2       110   265    1        0      130      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 285   46    1   0       140   311    0        1      120      1      1.8
# 289   55    0   0       128   205    0        2      130      1      2.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 301   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# 17       0   0     2       1
# 27       2   0     2       1
# ...

# %%
hd[hd["exang"]==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 5     57    1   0       140   192    0        1      148      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 293   67    1   2       152   212    0        0      150      0      0.8
# 297   59    1   0       164   176    1        0       90      0      1.0
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd["ca"]==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 296   63    0   0       124   197    0        1      136      1      0.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # Adding new col with applying some math

# %%
hd['prodata']=hd['chol']*hd['trestbps']
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  prodata
# 0        0   0     1       1    33785
# ...

# %% [markdown]
# ## col drop method

# %%
hd.drop('prodata',axis=1,inplace=True)
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # Cross Tab

# %%
hd.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
pd.crosstab(hd['sex'],hd['cp'])
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  52  19

# %%
pd.crosstab(hd['age'],hd['cp'])
# Out:
# cp    0  1  2  3
# age
# 29    0  1  0  0
# 34    0  1  0  1
# 35    3  1  0  0
# 37    0  0  2  0
# 38    0  0  2  1
# 39    1  0  3  0
# 40    2  0  0  1
# 41    1  6  3  0
# 42    3  1  3  1
# 43    6  0  2  0
# 44    3  3  5  0
# 45    4  3  0  1
# 46    3  2  2  0
# 47    2  0  3  0
# 48    3  2  2  0
# 49    1  2  2  0
# 50    3  1  3  0
# 51    4  0  7  1
# 52    5  3  3  2
# 53    5  0  3  0
# 54    6  3  7  0
# 55    5  3  0  0
# 56    5  4  1  1
# 57   11  3  3  0
# 58   10  3  5  1
# 59    7  1  2  4
# 60    7  0  3  1
# 61    6  0  1  1
# 62    7  2  2  0
# 63    6  1  1  1
# 64    5  0  3  2
# 65    4  0  3  1
# 66    4  1  1  1
# 67    6  0  3  0
# 68    1  0  3  0
# 69    0  0  1  2
# 70    2  1  1  0
# 71    1  1  1  0
# 74    0  1  0  0
# 76    0  0  1  0
# 77    1  0  0  0

# %%
pd.crosstab(hd['sex'],hd['target'])
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %%
pd.crosstab(hd['fbs'],hd['restecg'])
# Out:
# restecg    0    1  2
# fbs
# 0        121  133  4
# 1         26   19  0

# %%
pd.crosstab(hd['slope'],hd['ca'])
# Out:
# ca      0   1   2   3  4
# slope
# 0      15   2   2   2  0
# 1      69  35  21  13  2
# 2      91  28  15   5  3

# %% [markdown]
# # Special graph

# %%
hd.plot(kind='bar')
# Out:
# <Axes: >

# %%
hd['age'].plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.crosstab(hd['sex'],hd['cp']).plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# # Corealtion and heatmap

# %%
import seaborn as sns
correlation=hd.corr()
plt.figure(figsize=(10,6))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='2f',linewidth=0.5,cbar=True)
plt.show()

# %% [markdown]
# # Dencity plot

# %%
sns.kdeplot(hd["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(hd["chol"])
# Out:
# <Axes: xlabel='chol', ylabel='Density'>

# %%
sns.kdeplot(hd["ca"])
# Out:
# <Axes: xlabel='ca', ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.kdeplot(hd["sex"])
plt.subplot(1,2,2)
sns.kdeplot(hd["exang"])
plt.show()

# %%
plt.subplot(1,2,1)
sns.kdeplot(hd["exang"])
plt.subplot(1,2,2)
sns.kdeplot(hd["ca"])
plt.show()

# %%
plt.subplot(3,2,1)
sns.kdeplot(hd["exang"])
plt.subplot(3,2,2)
sns.kdeplot(hd["ca"])

plt.subplot(3,2,3)
sns.kdeplot(hd["sex"])
plt.subplot(3,2,4)
sns.kdeplot(hd["exang"])

plt.subplot(3,2,5)
sns.kdeplot(hd["exang"])
plt.subplot(3,2,6)
sns.kdeplot(hd["ca"])
plt.show()

# %% [markdown]
# #

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=hd["target"],y=hd["chol"],data=hd)
# Out:
# <Axes: xlabel='target', ylabel='chol'>

# %% [markdown]
# ![vimages.png](attachment:0020c4e4-2832-4717-acd7-8cadb8b12145.png)

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=hd["ca"],y=hd["sex"],data=hd)
# Out:
# <Axes: xlabel='ca', ylabel='sex'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(hd,alpha=0.2,figsize=(10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='sex', ylabel='age'>,
#         <Axes: xlabel='cp', ylabel='age'>,
#         <Axes: xlabel='trestbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='fbs', ylabel='age'>,
#         <Axes: xlabel='restecg', ylabel='age'>,
#         <Axes: xlabel='thalach', ylabel='age'>,
#         <Axes: xlabel='exang', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='slope', ylabel='age'>,
#         <Axes: xlabel='ca', ylabel='age'>,
#         <Axes: xlabel='thal', ylabel='age'>,
#         <Axes: xlabel='target', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='sex'>,
#         <Axes: xlabel='sex', ylabel='sex'>,
#         <Axes: xlabel='cp', ylabel='sex'>,
#         <Axes: xlabel='trestbps', ylabel='sex'>,
#         <Axes: xlabel='chol', ylabel='sex'>,
#         <Axes: xlabel='fbs', ylabel='sex'>,
#         <Axes: xlabel='restecg', ylabel='sex'>,
# ...
